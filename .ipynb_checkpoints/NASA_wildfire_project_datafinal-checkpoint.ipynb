# %% [markdown]
# # NASA Wildfire Data
#
# Notebook to pull NASA wildfire event data to .csv file

# %%
# Don't modify this cell.
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from pprint import pprint
import seaborn as sns

# API key not need for this data pull, but it does call an API for the data

# %% [markdown]
# ### Accessing the API and completing an API pull

# %%
# website and call for data
fire_url = 'https://eonet.sci.gsfc.nasa.gov/api/v3/categories/wildfires?status=closed'

fire_data = requests.get(fire_url).json()

# %%
# create dictionary to for read to dataframe
fire_dict = {'ID':[],
            'Name of Fire':[],
            'End Date':[],
             'Event Date':[],
             'Latitude':[],
             'Longitude': []
            }
#put all events in a list
fire_events_list = fire_data['events']

# loop over fire events list
for i in range(len(fire_events_list)): #for every event
    
    fire_dict['ID'].append(fire_events_list[i]['id'])
    fire_dict['Name of Fire'].append(fire_events_list[i]['title'])
    fire_dict['End Date'].append(fire_events_list[i]['closed'])
    fire_dict['Event Date'].append(fire_events_list[i]['geometry'][0]['date'])
    
    if fire_events_list[i]['geometry'][0]['type'] == 'Point':
        # Latitude is the second element in the coordinates list
        # Longitude is the first element in the coordinates list
        # GEOJSON geometry standard
        fire_dict['Latitude'].append(fire_events_list[i]['geometry'][0]['coordinates'][1])
        fire_dict['Longitude'].append(fire_events_list[i]['geometry'][0]['coordinates'][0])
    # if the fire event is a polygon (wide area), then we are just pulling one coordinate
    else:
        fire_dict['Latitude'].append(fire_events_list[i]['geometry'][0]['coordinates'][0][0][1])
        fire_dict['Longitude'].append(fire_events_list[i]['geometry'][0]['coordinates'][0][0][0])
#       print(i)   debugging statement

# %% [markdown]
# ### Adding Columns for year and month

# %%
fire_df = pd.DataFrame.from_dict(fire_dict)
fire_df['Year'] = pd.DatetimeIndex(fire_df['Event Date']).year
fire_df['Month'] = pd.DatetimeIndex(fire_df['Event Date']).month
fire_df.tail(20)
# Out:
#               ID                                       Name of Fire  \
# 1924    EONET_39               Fires in Eastern Russia, Summer 2015
# 1925    EONET_27                           Card Street Fire, Alaska
# 1926    EONET_36                        Red Canyon Fire, New Mexico
# 1927    EONET_23                               Sockeye Fire, Alaska
# 1928    EONET_22                              Buckskin Fire, Oregon
# 1929    EONET_19                       Chisana River 2 Fire, Alaska
# 1930    EONET_20                            Saddle Fire, California
# 1931     EONET_6                                     Guadalupe Fire
# 1932    EONET_11             Fires in Northern Territory, Australia
# 1933    EONET_12         Fires in Shoalwater, Queensland, Australia
# 1934    EONET_21  Democratic Republic of the Congo Fires, June 2015
# 1935    EONET_10                           Fires in Northern Canada
# 1936     EONET_4                                      Oak Tree Fire
# 1937    EONET_87                          Paradise Fire, Washington
# 1938     EONET_3                              Mud Lake Complex Fire
# 1939   EONET_180                Happy Camp Complex Fire, California
# 1940  EONET_2515            Paranorte, Mato Grasso, Brazil Wildfire
# 1941  EONET_2516                          Rondonia, Brazil Wildfire
# 1942  EONET_2514               Coniza, Mato Grosso, Brazil Wildfire
# 1943  EONET_2517            Itanhanga, Mato Grosso, Brazil Wildfire
#
#                   End Date            Event Date   Latitude   Longitude  Year  \
# 1924  2015-09-07T00:00:00Z  2015-06-16T00:00:00Z  49.586499   93.212891  2015
# 1925  2015-07-10T00:00:00Z  2015-06-15T00:00:00Z  60.454373 -150.693207  2015
# 1926  2015-07-08T00:00:00Z  2015-06-15T00:00:00Z  33.726394 -107.499084  2015
# 1927  2015-06-28T00:00:00Z  2015-06-14T00:00:00Z  61.735947 -150.168610  2015
# 1928  2015-06-30T00:00:00Z  2015-06-11T00:00:00Z  42.034809 -123.889313  2015
# 1929  2015-07-09T00:00:00Z  2015-06-09T00:00:00Z  62.411873 -141.766815  2015
# 1930  2015-06-24T00:00:00Z  2015-06-09T00:00:00Z  40.690452 -123.541527  2015
# 1931  2015-06-09T00:00:00Z  2015-06-02T00:00:00Z  31.451920 -109.047775  2015
# 1932  2015-06-08T00:00:00Z  2015-06-02T00:00:00Z -14.802302  128.964844  2015
# 1933  2015-06-08T00:00:00Z  2015-06-02T00:00:00Z -22.771940  149.827881  2015
# 1934  2015-06-13T00:00:00Z  2015-05-31T00:00:00Z -14.640992   22.109375  2015
# 1935  2015-07-16T00:00:00Z  2015-05-28T00:00:00Z  57.876421 -127.500000  2015
# 1936  2015-05-23T00:00:00Z  2015-05-20T00:00:00Z  31.808728 -110.708199  2015
# 1937  2015-09-03T00:00:00Z  2015-05-15T15:00:00Z  47.703611 -123.800556  2015
# 1938  2015-06-11T00:00:00Z  2015-05-08T00:00:00Z  25.962180  -81.167908  2015
# 1939  2015-09-02T00:00:00Z  2014-08-12T01:00:00Z  41.796389 -123.374167  2014
# 1940  2007-10-04T00:00:00Z  2007-08-03T00:00:00Z -10.460000  -57.860000  2007
# 1941  2005-10-14T00:00:00Z  2005-07-29T00:00:00Z  -9.160000  -61.730000  2005
# 1942  2005-10-12T00:00:00Z  2005-06-22T00:00:00Z  -9.390000  -59.250000  2005
# 1943  2003-12-19T00:00:00Z  2003-01-10T00:00:00Z -12.260000  -56.630000  2003
#
#       Month
# 1924      6
# 1925      6
# 1926      6
# 1927      6
# 1928      6
# 1929      6
# 1930      6
# 1931      6
# 1932      6
# 1933      6
# 1934      5
# 1935      5
# 1936      5
# 1937      5
# 1938      5
# 1939      8
# 1940      8
# 1941      7
# 1942      6
# 1943      1

# %%
#grouping
grouped_df = fire_df.groupby('Year')
print(grouped_df.count())

# Development of the EONET API started in 2015 so there is limited data prior to that. May not be able to see too much
# related to number of fires per year

grouped2_df = fire_df.groupby('Month')
grouped2_df.count()

# Will definitely see better data by month: And we have an answer to the question are there more fires in summer?- yes
# Out:
#        ID  Name of Fire  End Date  Event Date  Latitude  Longitude  Month
# Year
# 2003    1             1         1           1         1          1      1
# 2005    2             2         2           2         2          2      2
# 2007    1             1         1           1         1          1      1
# 2014    1             1         1           1         1          1      1
# 2015  159           159       159         159       159        159    159
# 2016  218           218       218         218       218        218    218
# 2017  420           420       420         420       420        420    420
# 2018  392           392       392         392       392        392    392
# 2019  294           294       294         294       294        294    294
# 2020  424           424       424         424       424        424    424
# 2021   32            32        32          32        32         32     32
#         ID  Name of Fire  End Date  Event Date  Latitude  Longitude  Year
# Month
# 1       45            45        45          45        45         45    45
# 2       51            51        51          51        51         51    51
# 3       45            45        45          45        45         45    45
# 4       59            59        59          59        59         59    59
# 5      117           117       117         117       117        117   117
# 6      265           265       265         265       265        265   265
# 7      477           477       477         477       477        477   477
# 8      537           537       537         537       537        537   537
# 9      164           164       164         164       164        164   164
# 10     104           104       104         104       104        104   104
# 11      43            43        43          43        43         43    43
# 12      37            37        37          37        37         37    37

# %% [markdown]
# ### Adding a column for hemispheres

# %%
hemispheres = []
latitude = fire_df['Latitude'].tolist()
for x in latitude:
    if x > 0:
        hemispheres.append('Northern Hemisphere')
    else:
        hemispheres.append('Southern Hemisphere')
len(hemispheres)
# Out:
# 1944

# %%
fire_df['Hemisphere'] = pd.Series(hemispheres)
fire_df.head(20)
# Out:
#             ID                                       Name of Fire  \
# 0   EONET_5285                                          Gila Fire
# 1   EONET_5272                                          King Fire
# 2   EONET_5268            Wildfires - Patagonia Region, Argentina
# 3   EONET_5267                                     Big Rocks Fire
# 4   EONET_5263  Wildfire - Curacavi Commune (Fundo Monterrey F...
# 5   EONET_5261               Wildfire - Tochigi Prefecture, Japan
# 6   EONET_5259             Wildfire - Gipuzkoa and Navarre, Spain
# 7   EONET_5258  Wildfire - Florida Commune (La Ermita Fire), C...
# 8   EONET_5246  Wildfire - NE of Pasadena, California - United...
# 9   EONET_5245            Wildfires - Alcudia Municipality, Spain
# 10  EONET_5243                                     Bent Twig Fire
# 11  EONET_5241  Wildfire - Lumaco Commune (Alto Renaico Fire),...
# 12  EONET_5242  Wildfire - Galvarino Commune (Los Temos Fire),...
# 13  EONET_5236     Wildfire - Perth, Western Australia, Australia
# 14  EONET_5225  Wildfires - La Estrella Commune (Las Chacras F...
# 15  EONET_5224  Wildfire - Monte Patria Commune (Rotonda Monte...
# 16  EONET_5223  Wildfire - San Fernando Commune ( El Portillo ...
# 17  EONET_5220                    Wildfire - Tirua Commune, Chile
# 18  EONET_5221              Wildfire - Alto Biobio Commune, Chile
# 19  EONET_5218  Wildfire - Santa Cruz (Panther Ridge Fire), Ca...
#
#                 End Date            Event Date   Latitude   Longitude  Year  \
# 0   2021-04-13T00:00:00Z  2021-04-02T07:15:00Z  32.914000 -113.437000  2021
# 1   2021-03-26T00:00:00Z  2021-03-17T15:30:00Z  26.953000  -98.088000  2021
# 2   2021-03-20T00:00:00Z  2021-03-12T14:42:00Z -42.591040  -71.384680  2021
# 3   2021-04-05T00:00:00Z  2021-03-08T16:30:00Z  37.740000 -115.001000  2021
# 4   2021-03-07T00:00:00Z  2021-03-01T18:46:00Z -33.387000  -71.197930  2021
# 5   2021-03-03T00:00:00Z  2021-02-25T16:10:00Z  36.360240  139.443260  2021
# 6   2021-03-01T00:00:00Z  2021-02-23T18:16:00Z  42.623870   -1.591170  2021
# 7   2021-02-28T00:00:00Z  2021-02-22T22:05:00Z -36.822950  -72.656940  2021
# 8   2021-02-17T00:00:00Z  2021-02-11T21:30:00Z  34.328913 -118.007215  2021
# 9   2021-02-16T00:00:00Z  2021-02-10T15:54:00Z  39.851700    3.124030  2021
# 10  2021-03-08T00:00:00Z  2021-02-05T17:45:00Z  32.565000  -99.477000  2021
# 11  2021-02-10T00:00:00Z  2021-02-05T14:44:00Z -38.202370  -72.856150  2021
# 12  2021-02-11T00:00:00Z  2021-02-05T14:40:00Z -38.458100  -72.819950  2021
# 13  2021-02-09T00:00:00Z  2021-02-01T19:54:00Z -31.762600  116.195960  2021
# 14  2021-02-02T00:00:00Z  2021-01-28T16:03:00Z -34.205430  -71.655190  2021
# 15  2021-02-07T00:00:00Z  2021-01-27T16:37:00Z -30.697800  -70.961030  2021
# 16  2021-02-02T00:00:00Z  2021-01-27T16:34:00Z -34.881490  -70.837440  2021
# 17  2021-02-01T00:00:00Z  2021-01-22T16:15:00Z -38.345030  -73.479850  2021
# 18  2021-01-28T00:00:00Z  2021-01-22T16:13:00Z -37.892410  -71.638890  2021
# 19  2021-01-26T00:00:00Z  2021-01-20T15:38:00Z  37.010860 -122.040390  2021
#
#     Month           Hemisphere
# 0       4  Northern Hemisphere
# 1       3  Northern Hemisphere
# 2       3  Southern Hemisphere
# 3       3  Northern Hemisphere
# 4       3  Southern Hemisphere
# 5       2  Northern Hemisphere
# 6       2  Northern Hemisphere
# 7       2  Southern Hemisphere
# 8       2  Northern Hemisphere
# 9       2  Northern Hemisphere
# 10      2  Northern Hemisphere
# 11      2  Southern Hemisphere
# 12      2  Southern Hemisphere
# 13      2  Southern Hemisphere
# 14      1  Southern Hemisphere
# 15      1  Southern Hemisphere
# 16      1  Southern Hemisphere
# 17      1  Southern Hemisphere
# 18      1  Southern Hemisphere
# 19      1  Northern Hemisphere

# %%
groupby_hemi_df = fire_df.groupby('Hemisphere')
groupby_hemi_df.count()
# Out:
#                        ID  Name of Fire  End Date  Event Date  Latitude  \
# Hemisphere
# Northern Hemisphere  1772          1772      1772        1772      1772
# Southern Hemisphere   172           172       172         172       172
#
#                      Longitude  Year  Month
# Hemisphere
# Northern Hemisphere       1772  1772   1772
# Southern Hemisphere        172   172    172

# %% [markdown]
# ### Adding country data from the latitude and longitude

# %%
# using a function to pull country data
from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'student_project')

# %%
#do not rerun
countryList = []
print(len(fire_df))
# Out:
# 1944

# %%
# Adding country data for those points where a country is listed
# if no country, use "Missing Data"
# warning when it looks like Lat and Lon were switched
for i in range(len(fire_df)):
    
    try:
        location = geocoder.reverse((fire_df.loc[i,'Latitude'], fire_df.loc[i,'Longitude']))
        countryList.append(location.raw['address']['country'])
    except:
        countryList.append('Missing Data')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/geopy/point.py:472: UserWarning: Latitude normalization has been prohibited in the newer versions of geopy, because the normalized value happened to be on a different pole, which is probably not what was meant. If you pass coordinates as positional args, please make sure that the order is (latitude, longitude) or (y, x) in Cartesian terms.
#   return cls(*args)

# %%
len(countryList)
#pprint(countryList)
# Out:
# 1944

# %%
fire_df.loc[1454]

#This fire event has the data for latitude and longitude reversed.
# We fixed this data in the data analysis notebook.
# Out:
# ID                                                     EONET_3014
# Name of Fire    C11014 - East of Toil Mtn - Quesnel West Fire,...
# End Date                                     2017-07-31T00:00:00Z
# Event Date                                   2017-07-07T00:00:00Z
# Latitude                                               -124.02195
# Longitude                                               52.810817
# Year                                                         2017
# Month                                                           7
# Hemisphere                                    Southern Hemisphere
# Name: 1454, dtype: object

# %%
#adding column for 'Country' with list of countries
fire_df['Country'] = pd.Series(countryList)

# %%
fire_df.head(20)
# Out:
#             ID                                       Name of Fire  \
# 0   EONET_5285                                          Gila Fire
# 1   EONET_5272                                          King Fire
# 2   EONET_5268            Wildfires - Patagonia Region, Argentina
# 3   EONET_5267                                     Big Rocks Fire
# 4   EONET_5263  Wildfire - Curacavi Commune (Fundo Monterrey F...
# 5   EONET_5261               Wildfire - Tochigi Prefecture, Japan
# 6   EONET_5259             Wildfire - Gipuzkoa and Navarre, Spain
# 7   EONET_5258  Wildfire - Florida Commune (La Ermita Fire), C...
# 8   EONET_5246  Wildfire - NE of Pasadena, California - United...
# 9   EONET_5245            Wildfires - Alcudia Municipality, Spain
# 10  EONET_5243                                     Bent Twig Fire
# 11  EONET_5241  Wildfire - Lumaco Commune (Alto Renaico Fire),...
# 12  EONET_5242  Wildfire - Galvarino Commune (Los Temos Fire),...
# 13  EONET_5236     Wildfire - Perth, Western Australia, Australia
# 14  EONET_5225  Wildfires - La Estrella Commune (Las Chacras F...
# 15  EONET_5224  Wildfire - Monte Patria Commune (Rotonda Monte...
# 16  EONET_5223  Wildfire - San Fernando Commune ( El Portillo ...
# 17  EONET_5220                    Wildfire - Tirua Commune, Chile
# 18  EONET_5221              Wildfire - Alto Biobio Commune, Chile
# 19  EONET_5218  Wildfire - Santa Cruz (Panther Ridge Fire), Ca...
#
#                 End Date            Event Date   Latitude   Longitude  Year  \
# 0   2021-04-13T00:00:00Z  2021-04-02T07:15:00Z  32.914000 -113.437000  2021
# 1   2021-03-26T00:00:00Z  2021-03-17T15:30:00Z  26.953000  -98.088000  2021
# 2   2021-03-20T00:00:00Z  2021-03-12T14:42:00Z -42.591040  -71.384680  2021
# 3   2021-04-05T00:00:00Z  2021-03-08T16:30:00Z  37.740000 -115.001000  2021
# 4   2021-03-07T00:00:00Z  2021-03-01T18:46:00Z -33.387000  -71.197930  2021
# 5   2021-03-03T00:00:00Z  2021-02-25T16:10:00Z  36.360240  139.443260  2021
# 6   2021-03-01T00:00:00Z  2021-02-23T18:16:00Z  42.623870   -1.591170  2021
# 7   2021-02-28T00:00:00Z  2021-02-22T22:05:00Z -36.822950  -72.656940  2021
# 8   2021-02-17T00:00:00Z  2021-02-11T21:30:00Z  34.328913 -118.007215  2021
# 9   2021-02-16T00:00:00Z  2021-02-10T15:54:00Z  39.851700    3.124030  2021
# 10  2021-03-08T00:00:00Z  2021-02-05T17:45:00Z  32.565000  -99.477000  2021
# 11  2021-02-10T00:00:00Z  2021-02-05T14:44:00Z -38.202370  -72.856150  2021
# 12  2021-02-11T00:00:00Z  2021-02-05T14:40:00Z -38.458100  -72.819950  2021
# 13  2021-02-09T00:00:00Z  2021-02-01T19:54:00Z -31.762600  116.195960  2021
# 14  2021-02-02T00:00:00Z  2021-01-28T16:03:00Z -34.205430  -71.655190  2021
# 15  2021-02-07T00:00:00Z  2021-01-27T16:37:00Z -30.697800  -70.961030  2021
# 16  2021-02-02T00:00:00Z  2021-01-27T16:34:00Z -34.881490  -70.837440  2021
# 17  2021-02-01T00:00:00Z  2021-01-22T16:15:00Z -38.345030  -73.479850  2021
# 18  2021-01-28T00:00:00Z  2021-01-22T16:13:00Z -37.892410  -71.638890  2021
# 19  2021-01-26T00:00:00Z  2021-01-20T15:38:00Z  37.010860 -122.040390  2021
#
#     Month           Hemisphere        Country
# 0       4  Northern Hemisphere  United States
# 1       3  Northern Hemisphere  United States
# 2       3  Southern Hemisphere      Argentina
# 3       3  Northern Hemisphere  United States
# 4       3  Southern Hemisphere          Chile
# 5       2  Northern Hemisphere             日本
# 6       2  Northern Hemisphere         España
# 7       2  Southern Hemisphere          Chile
# 8       2  Northern Hemisphere  United States
# 9       2  Northern Hemisphere         España
# 10      2  Northern Hemisphere  United States
# 11      2  Southern Hemisphere          Chile
# 12      2  Southern Hemisphere          Chile
# 13      2  Southern Hemisphere      Australia
# 14      1  Southern Hemisphere          Chile
# 15      1  Southern Hemisphere          Chile
# 16      1  Southern Hemisphere          Chile
# 17      1  Southern Hemisphere          Chile
# 18      1  Southern Hemisphere          Chile
# 19      1  Northern Hemisphere  United States

# %%
fire_df['Country'].value_counts()
# Out:
# United States                     1381
# Canada                             272
# Chile                              101
# Australia                           37
# España                              22
# Portugal                            11
# Schweiz/Suisse/Svizzera/Svizra       9
# Ελλάς                                9
# Italia                               7
# South Africa                         7
# France                               7
# Missing Data                         5
# New Zealand / Aotearoa               4
# Brasil                               4
# México                               4
# Argentina                            4
# Україна                              4
# Deutschland                          4
# Россия                               3
# Latvija                              3
# Sverige                              3
# Kalaallit Nunaat                     2
# Slovenija                            2
# Монгол улс ᠮᠤᠩᠭᠤᠯ ᠤᠯᠤᠰ               2
# Perú                                 2
# Algérie / ⵍⵣⵣⴰⵢⴻⵔ / الجزائر          2
# Indonesia                            2
# Bolivia                              2
# საქართველო                           2
# United Kingdom                       2
# 中国                                   2
# Kenya                                2
# ישראל                                2
# Crna Gora / Црна Гора                1
# سوريا                                1
# Norge                                1
# India                                1
# لبنان                                1
# Nederland                            1
# Zambia                               1
# Lietuva                              1
# မြန်မာ                               1
# 日本                                   1
# Panamá                               1
# Colombia                             1
# Uruguay                              1
# Palestinian Territory                1
# Venezuela                            1
# Shqipëria                            1
# Ecuador                              1
# Honduras                             1
# Κύπρος - Kıbrıs                      1
# Name: Country, dtype: int64

# %%
missing_country = fire_df[fire_df['Country'] == "Missing Data"]
missing_country

# only a few missing data points
# Out:
#               ID                                       Name of Fire  \
# 1141  EONET_3436                Southeast Asia Agricultural Burning
# 1454  EONET_3014  C11014 - East of Toil Mtn - Quesnel West Fire,...
# 1778   EONET_333                             Bushfires, NW Tasmania
# 1781   EONET_235                         Esperance Fires, Australia
# 1824   EONET_199                         Indonesia Fires, Fall 2015
#
#                   End Date            Event Date    Latitude   Longitude  \
# 1141  2018-03-31T00:00:00Z  2018-01-01T00:00:00Z    8.960163   96.445312
# 1454  2017-07-31T00:00:00Z  2017-07-07T00:00:00Z -124.021950   52.810817
# 1778  2016-02-15T00:00:00Z  2016-01-14T00:00:00Z  -42.233246  144.543457
# 1781  2015-11-24T00:00:00Z  2015-11-18T00:00:00Z  -34.203455  121.120605
# 1824  2015-10-31T00:00:00Z  2015-08-14T00:00:00Z   -6.474497  100.488281
#
#       Year  Month           Hemisphere       Country
# 1141  2018      1  Northern Hemisphere  Missing Data
# 1454  2017      7  Southern Hemisphere  Missing Data
# 1778  2016      1  Southern Hemisphere  Missing Data
# 1781  2015     11  Southern Hemisphere  Missing Data
# 1824  2015      8  Southern Hemisphere  Missing Data

# %% [markdown]
# ### Write dataframe to .csv file for use in the data analysis
#
# fire_data.csv will be read into another notebook for data analysis

# %%
fire_df.to_csv('fire_data.csv')
